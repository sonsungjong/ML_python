# %%
# EDA : Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_groceries = pd.read_excel('./Data/Groceries.xlsx')
df_groceries.head(10)
# Out:
#   Product_ID            Category                  Item  Price_Dollars  \
# 0    P100010      Produce: Fruit                 Apple           1.50
# 1    P100011      Produce: Fruit                Banana           0.40
# 2    P100012      Produce: Fruit                Grapes           4.00
# 3    P100013      Produce: Fruit            Grapefruit           0.99
# 4    P100014      Produce: Fruit  Organic Strawberries           3.99
# 5    P100015      Produce: Fruit            Watermelon           5.99
# 6    P100016  Produce: Vegetable               Cabbage           1.78
# 7    P100017  Produce: Vegetable               Carrots           2.00
# 8    P100018  Produce: Vegetable                Celery           1.99
# 9    P100019  Produce: Vegetable              Cucumber           0.99
#
#    Inventory        Last_Updated Next_Scheduled_Shipment
# 0        349 2023-06-12 15:35:00              2023-06-15
# 1        500 2023-06-12 18:30:00              2023-06-15
# ...

# %%
# 서브카테고리 기준으로 평균가격 보고 싶다
df_groceries.groupby('Category')['Price_Dollars'].mean().plot.bar();

# %%
# 서브카테고리 기준으로 평균가격 보고 싶다
df_groceries.groupby('Category')['Price_Dollars'].mean().sort_values().plot.barh();

# %%
# 행복지수 시각화
df_happiness = pd.read_csv('./Data/happiness_survey_data.csv')
df_happiness.head()
# Out:
#   country_name  year  happiness_score  social_support  \
# 0  Afghanistan  2008         3.723590        0.450662
# 1  Afghanistan  2009         4.401778        0.552308
# 2  Afghanistan  2010         4.758381        0.539075
# 3  Afghanistan  2011         3.831719        0.521104
# 4  Afghanistan  2012         3.782938        0.520637
#
#    freedom_to_make_life_choices  healthy_life_expectancy_at_birth
# 0                      0.718114                         50.500000
# 1                      0.678896                         50.799999
# 2                      0.600127                         51.099998
# 3                      0.495901                         51.400002
# 4                      0.530935                         51.700001

# %%
df_happiness[df_happiness.country_name.str.lower() == 'mexico'].iloc[:, 1:3].plot.line(x='year', y='happiness_score')
# Out:
# <Axes: xlabel='year'>

# %%
# 캐나다, 멕시코, 미국
(df_happiness[df_happiness.country_name.str.lower()
.isin(['canada', 'mexico', 'united states'])]
.iloc[:, :3]
.pivot(index='year', columns='country_name', values='happiness_score')
.plot.line())
# Out:
# <Axes: xlabel='year'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_student_data = pd.read_csv('./Data/student_data.csv')
df_student_data.head()
# Out:
#    Hours of Sleep  Hours Studied  Grade on Test  Grade in Class  \
# 0       10.602667       4.586892             99       99.187294
# 1        8.172997       4.405120             72       67.070903
# 2        6.430132       0.519630             52       39.644696
# 3        7.963793       5.004348             80       61.843705
# 4        8.279421       2.984489             87      103.495002
#
#    Cups of Coffee
# 0               5
# 1               3
# 2               4
# 3               1
# 4               0

# %%
sns.pairplot(df_student_data)

# %%
df_student_data['Cups of Coffee'].value_counts().sort_index()
# Out:
# Cups of Coffee
# 0     35
# 1     67
# 2     44
# 3     38
# 4      6
# 5      5
# 6      3
# 8      1
# 10     1
# Name: count, dtype: int64

# %%
sns.histplot(df_student_data['Cups of Coffee']);
